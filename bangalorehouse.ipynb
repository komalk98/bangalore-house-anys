# %% [markdown]
# <a href="https://colab.research.google.com/github/komalk98/bangalore-house-anys/blob/main/bangalorehouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
bang = pd.read_csv('/content/sample_data/Bangalore  house data.csv')

# %%
bang.head(10)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
# 5  Super built-up  Area  Ready To Move  ...     1.0   38.00
# 6  Super built-up  Area         18-May  ...     NaN  204.00
# 7  Super built-up  Area  Ready To Move  ...     NaN  600.00
# 8  Super built-up  Area  Ready To Move  ...     1.0   63.25
# 9            Plot  Area  Ready To Move  ...     NaN  370.00
#
# [10 rows x 9 columns]

# %%
bang.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
bang.count()
# Out:
# area_type       13320
# availability    13320
# location        13319
# size            13304
# society          7818
# total_sqft      13320
# bath            13247
# balcony         12711
# price           13320
# dtype: int64

# %%
bang.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(bang.isnull())
plt.show()

# %%
bang.head(10)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
# 5  Super built-up  Area  Ready To Move  ...     1.0   38.00
# 6  Super built-up  Area         18-May  ...     NaN  204.00
# 7  Super built-up  Area  Ready To Move  ...     NaN  600.00
# 8  Super built-up  Area  Ready To Move  ...     1.0   63.25
# 9            Plot  Area  Ready To Move  ...     NaN  370.00
#
# [10 rows x 9 columns]

# %%
bang.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
# bang.availability = pd.to_datetime(bang.availability)

# %%
bang.head(2)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
#
# [2 rows x 9 columns]

# %%
df1 = bang[bang['location'] == 'Marathahalli']
df1.head(2)
# Out:
#                area_type   availability      location  ... bath balcony  price
# 8   Super built-up  Area  Ready To Move  Marathahalli  ...  3.0     1.0  63.25
# 67  Super built-up  Area  Ready To Move  Marathahalli  ...  2.0     1.0  57.00
#
# [2 rows x 9 columns]

# %%
df1.groupby('size').price.mean()
# Out:
# size
# 1 BHK         49.400000
# 2 BHK         64.192133
# 2 Bedroom    115.500000
# 3 BHK         94.306290
# 4 BHK        208.100000
# 4 Bedroom    283.285714
# 5 Bedroom    167.500000
# 6 Bedroom    108.000000
# 7 Bedroom    160.000000
# Name: price, dtype: float64

# %%
bang.groupby('society').price.min().sort_values(ascending=False).head(10)
# Out:
# society
# Kierser    2700.0
# Adion A    1800.0
# Epllan     1675.0
# Phaku K    1500.0
# LeeyaCa    1063.0
# Niateki    1015.0
# HMeuran     988.0
# Masta A     986.0
# ImncyTa     950.0
# Prian E     948.0
# Name: price, dtype: float64

# %%
bang.head(2)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
#
# [2 rows x 9 columns]

# %% [markdown]
# # *total count of records of each area where price is less than given number *

# %%
bang[bang.price < 20].area_type.value_counts()
# Out:
# Super built-up  Area    107
# Built-up  Area           47
# Plot  Area                7
# Carpet  Area              3
# Name: area_type, dtype: int64
